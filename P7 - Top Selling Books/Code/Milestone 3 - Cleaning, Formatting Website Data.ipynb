# %%
# Load necessary libraries
import pandas as pd
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process

# %%
source_url = 'https://en.wikipedia.org/wiki/List_of_best-selling_books'

# %%
df0 = pd.read_html(source_url)[0]
df1 = pd.read_html(source_url)[1]
df2 = pd.read_html(source_url)[2]
df3 = pd.read_html(source_url)[3]
df4 = pd.read_html(source_url)[4]

# %%
# Append all makes dataframes to single dataframe
books_df = df0.append([df1, df2, df3, df4])

# %%
books_df
# Out:
#                                                  Book  \
# 0                                A Tale of Two Cities
# 1                 The Little Prince (Le Petit Prince)
# 2                               The Lord of the Rings
# 3                                          The Hobbit
# 4            Harry Potter and the Philosopher's Stone
# ..                                                ...
# 59                                   The Front Runner
# 60                                           The Goal
# 61                                     Fahrenheit 451
# 62                                     Angela's Ashes
# 63  The Story of My Experiments with Truth (સત્યના...
#
#                      Author(s) Original language First published  \
# 0              Charles Dickens           English            1859
# 1     Antoine de Saint-Exupéry            French            1943
# 2             J. R. R. Tolkien           English            1954
# 3             J. R. R. Tolkien           English            1937
# 4                 J. K Rowling           English            1997
# ..                         ...               ...             ...
# 59        Patricia Nell Warren           English            1974
# 60         Eliyahu M. Goldratt           English            1984
# 61                Ray Bradbury           English            1953
# 62               Frank McCourt           English            1996
# 63  Mohandas Karamchand Gandhi          Gujarati       1925-1929
#
#           Approximate sales                   Genre
# 0           200 million[15]      Historical fiction
# 1   150 million[16][17][18]  Fantasy (picture book)
# 2           150 million[19]                 Fantasy
# 3           150 million[20]                 Fantasy
# 4      120 million [21][22]        Fantasy, mystery
# ..                      ...                     ...
# 59          10 million[171]                     NaN
# 60          10 million[172]                     NaN
# 61          10 million[173]                     NaN
# 62          10 million[174]                     NaN
# 63          10 million[175]                     NaN
#
# [167 rows x 6 columns]

# %%
# Reset index
books_df = books_df.reset_index(drop=True)
books_df
# Out:
#                                                   Book  \
# 0                                 A Tale of Two Cities
# 1                  The Little Prince (Le Petit Prince)
# 2                                The Lord of the Rings
# 3                                           The Hobbit
# 4             Harry Potter and the Philosopher's Stone
# ..                                                 ...
# 162                                   The Front Runner
# 163                                           The Goal
# 164                                     Fahrenheit 451
# 165                                     Angela's Ashes
# 166  The Story of My Experiments with Truth (સત્યના...
#
#                       Author(s) Original language First published  \
# 0               Charles Dickens           English            1859
# 1      Antoine de Saint-Exupéry            French            1943
# 2              J. R. R. Tolkien           English            1954
# 3              J. R. R. Tolkien           English            1937
# 4                  J. K Rowling           English            1997
# ..                          ...               ...             ...
# 162        Patricia Nell Warren           English            1974
# 163         Eliyahu M. Goldratt           English            1984
# 164                Ray Bradbury           English            1953
# 165               Frank McCourt           English            1996
# 166  Mohandas Karamchand Gandhi          Gujarati       1925-1929
#
#            Approximate sales                   Genre
# 0            200 million[15]      Historical fiction
# 1    150 million[16][17][18]  Fantasy (picture book)
# 2            150 million[19]                 Fantasy
# 3            150 million[20]                 Fantasy
# 4       120 million [21][22]        Fantasy, mystery
# ..                       ...                     ...
# 162          10 million[171]                     NaN
# 163          10 million[172]                     NaN
# 164          10 million[173]                     NaN
# 165          10 million[174]                     NaN
# 166          10 million[175]                     NaN
#
# [167 rows x 6 columns]

# %%
for col in books_df.columns: 
    print(col)
# Out:
# Book
# Author(s)
# Original language
# First published
# Approximate sales
# Genre

# %%
# Replace headers
books_df1 = books_df.rename(columns={"Book": "Book_Name", "Author(s)": "Author_Name", "Approximate sales": "Copies_sold"})
books_df1.head()
# Out:
#                                   Book_Name               Author_Name  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2                     The Lord of the Rings          J. R. R. Tolkien
# 3                                The Hobbit          J. R. R. Tolkien
# 4  Harry Potter and the Philosopher's Stone              J. K Rowling
#
#   Original language First published              Copies_sold  \
# 0           English            1859          200 million[15]
# 1            French            1943  150 million[16][17][18]
# 2           English            1954          150 million[19]
# 3           English            1937          150 million[20]
# 4           English            1997     120 million [21][22]
#
#                     Genre
# 0      Historical fiction
# 1  Fantasy (picture book)
# 2                 Fantasy
# 3                 Fantasy
# 4        Fantasy, mystery

# %%
# Create a dataframe without Genre since they are not populated for books which have sold less then 50 million copies
books_df2 = books_df1[['Book_Name', 'Author_Name', 'Original language', 'First published', 'Copies_sold']]
books_df2.head()
# Out:
#                                   Book_Name               Author_Name  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2                     The Lord of the Rings          J. R. R. Tolkien
# 3                                The Hobbit          J. R. R. Tolkien
# 4  Harry Potter and the Philosopher's Stone              J. K Rowling
#
#   Original language First published              Copies_sold
# 0           English            1859          200 million[15]
# 1            French            1943  150 million[16][17][18]
# 2           English            1954          150 million[19]
# 3           English            1937          150 million[20]
# 4           English            1997     120 million [21][22]

# %%
# Format data into a more readable format
# While we read the data from the website, copies sold also has the references along with other data. So we will remove them to make it more readable.

i = 0
while i < 166:
  books_df2['Copies_sold'][i] = books_df2['Copies_sold'][i].split(' ')[0]
  books_df2['Copies_sold'][i] = books_df2['Copies_sold'][i] + ' Million'
  i += 1
books_df2.head()
# Out:
# /Users/vinaynagaraj/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                   Book_Name               Author_Name  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2                     The Lord of the Rings          J. R. R. Tolkien
# 3                                The Hobbit          J. R. R. Tolkien
# 4  Harry Potter and the Philosopher's Stone              J. K Rowling
#
#   Original language First published  Copies_sold
# 0           English            1859  200 Million
# 1            French            1943  150 Million
# 2           English            1954  150 Million
# 3           English            1937  150 Million
# 4           English            1997  120 Million

# %%
# Find duplicates in our data frame based on Book Name
duplicateRowsDF = books_df2[books_df1.duplicated(['Book_Name'])]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [Book_Name, Author_Name, Original language, First published, Copies_sold]
# Index: []

# %% [markdown]
# As per above results, we can see that there are no duplicates in this dataframe

# %%
#Check for any missing value and display the stats
books_df2.isnull().sum()
# Out:
# Book_Name            0
# Author_Name          0
# Original language    0
# First published      0
# Copies_sold          0
# dtype: int64

# %%
# Fuzzy matching on Author Name
choices = books_df2['Author_Name'].unique()
choices[:15]
# Out:
# array(['Charles Dickens', 'Antoine de Saint-Exupéry', 'J. R. R. Tolkien',
#        'J. K Rowling', 'Agatha Christie', 'Cao Xueqin', 'C. S. Lewis',
#        'H. Rider Haggard', 'Carlo Collodi', 'Dan Brown', 'J. K. Rowling',
#        'Paulo Coelho', 'J. D. Salinger', 'Robert James Waller',
#        'Lew Wallace'], dtype=object)

# %%
process.extract("Rowling", choices, limit=30, scorer=fuzz.token_sort_ratio)
# Out:
# [('J. K Rowling', 78),
#  ('J. K. Rowling', 78),
#  ('J. R. R. Tolkien', 50),
#  ('Dan Brown', 50),
#  ('Jiang Rong', 47),
#  ('Mark Twain', 47),
#  ('Erica Jong', 47),
#  ('William P. Young', 45),
#  ('Astrid Lindgren', 45),
#  ('J. D. Salinger', 42),
#  ('Irving Stone', 42),
#  ('Carlo Collodi', 40),
#  ('George Orwell', 40),
#  ('Stieg Larsson', 40),
#  ('Margaret Wise Brown', 38),
#  ('Charles Dickens', 36),
#  ('Jostein Gaarder', 36),
#  ('William Bradford Huie', 36),
#  ('Suzanne Collins', 36),
#  ('Stephen Hawking', 36),
#  ('Cao Xueqin', 35),
#  ('Eric Carle', 35),
#  ('Carl Sagan', 35),
#  ('Wayne Dyer', 35),
#  ('John Green', 35),
#  ('Roald Dahl', 35),
#  ('Carlos Ruiz Zafón', 35),
#  ('Erskine Caldwell', 35),
#  ('Ernest Hemingway', 35),
#  ('Janette Sebring Lowrey', 34)]

# %%
# Write Final Dataframe into CSV file
books_df2.to_csv('Website_Books_cleaned.csv')
